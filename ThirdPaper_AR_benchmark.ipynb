# %%
from statsmodels.tsa.ar_model import AutoReg
import numpy as np
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler
import pandas as pd

# %%
#import the data
df = pd.read_csv('/Users/gadimg/Library/Mobile Documents/com~apple~CloudDocs/PhD dis/third/Data/Merged_data/Full_with_otherCrypto+mothly.csv', parse_dates=['Date'], dayfirst=True)

# Difference the data
df_diff = df.drop(columns=['Date']).diff().dropna()

# Normalize the entire differenced dataset
scaler = StandardScaler()
df_normalized = pd.DataFrame(scaler.fit_transform(df_diff), columns=df_diff.columns)

# Prepare the data
Y = df_normalized['ETH_Price'].values
X = df_normalized.drop(columns=['ETH_Price']).values

# Number of observations
n = len(df_normalized)

# %%
# Your Y and start are already defined from the Lasso part
# Recursive window prediction for AR model, straight up with 7 lags
start = n - 100

ar_predictions = []

for i in range(start, n):
    # Define the training data up to point i
    y_train_ar = Y[:i]
    
    # Fit the AR model - we'll use a fixed lag of 7, you might have to adjust based on your previous criteria
    ar_model = AutoReg(y_train_ar, lags=1, old_names=False).fit()
    
    # Make the one-step-ahead forecast
    y_pred_ar = ar_model.predict(start=i, end=i)
    ar_predictions.append(y_pred_ar[0])

# Calculate RMSE for the AR predictions
ar_rmse = np.sqrt(mean_squared_error(Y[start:], ar_predictions))
print(f"AR Model RMSE for the last 100 values: {ar_rmse}")
# Out:
# AR Model RMSE for the last 100 values: 0.2758212041945253

# %%
#determining the appropriate lags 

from statsmodels.tsa.stattools import adfuller

# Make sure your series is stationary
result = adfuller(Y)
if result[1] < 0.05:
    print("The series is stationary.")
    optimal_lag = None
    best_aic = np.inf
    
    # Determine the optimal number of lags using AIC on the full dataset
    for lag in range(1, 8):  # You can adjust the range of lags you want to test
        model = AutoReg(Y, lags=lag, old_names=False).fit()
        if model.aic < best_aic:
            best_aic = model.aic
            optimal_lag = lag

    print(f"Optimal number of lags based on full data AIC: {optimal_lag}")
else:
    print("The series is not stationary. Make it stationary before applying AR model.")
# Out:
# The series is stationary.
# Optimal number of lags based on full data AIC: 6

# %%
# Continue with the recursive window prediction using the optimal lag
ar_predictions = []
for i in range(start, n):
    y_train_ar = Y[:i]
    ar_model = AutoReg(y_train_ar, lags=optimal_lag, old_names=False).fit()
    y_pred_ar = ar_model.predict(start=i, end=i)
    ar_predictions.append(y_pred_ar[0])

# Calculate RMSE for the AR predictions
ar_rmse = np.sqrt(mean_squared_error(Y[start:], ar_predictions))
print(f"AR Model RMSE for the last 100 values: {ar_rmse}")
# Out:
# AR Model RMSE for the last 100 values: 0.28135957450308663

# %%
#testiing for stationarity
from statsmodels.tsa.stattools import adfuller

def adf_test(series, column_name):
    result = adfuller(series, autolag='AIC')
    print(f'Stationarity test for {column_name}')
    print(f'ADF Statistic: {result[0]}')
    print(f'p-value: {result[1]}')
    for key, value in result[4].items():
        print(f'Critical Value ({key}): {value}')
    print('')

# Test for stationarity on the original dataframe before normalization
for column in df.columns:
    if column != 'Date':  # Skip the 'Date' column
        adf_test(df[column], column)

# Test for stationarity on the normalized dataframe
for column in df_normalized.columns:
    adf_test(df_normalized[column], column)
# Out:
# Stationarity test for ETH_Price
# ADF Statistic: -2.0876050751855173
# p-value: 0.2495277831325552
# Critical Value (1%): -3.4360194465416387
# Critical Value (5%): -2.8640434537995523
# Critical Value (10%): -2.5681028978640104
#
# Stationarity test for ETH_Volume
# ADF Statistic: -2.803682634596565
# p-value: 0.05774965237684188
# Critical Value (1%): -3.4360941478268767
# Critical Value (5%): -2.864076408006588
# Critical Value (10%): -2.568120448620112
#
# Stationarity test for BTC_Price
# ADF Statistic: -1.9093981994300466
# p-value: 0.32765289963049593
# Critical Value (1%): -3.4359901072390353
# Critical Value (5%): -2.86403051064684
# Critical Value (10%): -2.5680960046332366
#
# Stationarity test for BTC_Volume
# ADF Statistic: -2.8876368527291216
# p-value: 0.04680466753474846
# Critical Value (1%): -3.4360540638753405
# Critical Value (5%): -2.864058725215095
# Critical Value (10%): -2.568111031100567
#
# Stationarity test for LINK_number_of_transfers
# ADF Statistic: -4.014484254400848
# p-value: 0.0013365378855441038
# Critical Value (1%): -3.4360540638753405
# Critical Value (5%): -2.864058725215095
# Critical Value (10%): -2.568111031100567
#
# Stationarity test for LINK_on_chain_volume
# ADF Statistic: -6.056187889379939
# p-value: 1.2435503563679429e-07
# Critical Value (1%): -3.4360540638753405
# Critical Value (5%): -2.864058725215095
# Critical Value (10%): -2.568111031100567
#
# Stationarity test for LINK_Price
# ADF Statistic: -1.6075866432789763
# p-value: 0.4797814585135796
# Critical Value (1%): -3.4360941478268767
# Critical Value (5%): -2.864076408006588
# Critical Value (10%): -2.568120448620112
#
# Stationarity test for LINK_Volume
# ADF Statistic: -15.042418724415858
# p-value: 9.550466975336716e-28
# Critical Value (1%): -3.4360047388340984
# Critical Value (5%): -2.8640369654502846
# Critical Value (10%): -2.5680994423132613
#
# Stationarity test for GWEI_average_daily_gas_price_gwei
# ADF Statistic: -2.6680370228265686
# p-value: 0.079734441066867
# Critical Value (1%): -3.4360941478268767
# Critical Value (5%): -2.864076408006588
# Critical Value (10%): -2.568120448620112
#
# Stationarity test for WBTC_number_of_transfers
# ADF Statistic: -5.601451545402651
# p-value: 1.2620461598581073e-06
# Critical Value (1%): -3.4360194465416387
# Critical Value (5%): -2.8640434537995523
# Critical Value (10%): -2.5681028978640104
#
# Stationarity test for WBTC_on_chain_volume
# ADF Statistic: -4.021500869863015
# p-value: 0.00130201789347722
# Critical Value (1%): -3.4361042569951805
# Critical Value (5%): -2.8640808675675826
# Critical Value (10%): -2.568122823703617
#
# Stationarity test for WBTC_Price
# ADF Statistic: -1.9182038579351386
# p-value: 0.3235464931616794
# Critical Value (1%): -3.4359901072390353
# Critical Value (5%): -2.86403051064684
# Critical Value (10%): -2.5680960046332366
#
# Stationarity test for WBTC_Volume
# ADF Statistic: -4.302983569139879
# p-value: 0.00043895732793747103
# Critical Value (1%): -3.4360540638753405
# Critical Value (5%): -2.864058725215095
# Critical Value (10%): -2.568111031100567
#
# Stationarity test for USDT_number_of_transfers
# ADF Statistic: -1.8757880806573968
# p-value: 0.3435354647024899
# Critical Value (1%): -3.4360941478268767
# Critical Value (5%): -2.864076408006588
# Critical Value (10%): -2.568120448620112
#
# Stationarity test for USDT_on_chain_volume
# ADF Statistic: -4.258080581542864
# p-value: 0.00052461729945222
# Critical Value (1%): -3.4360991979671205
# Critical Value (5%): -2.864078635828568
# Critical Value (10%): -2.568121635118498
#
# Stationarity test for USDT_Price
# ADF Statistic: -5.36718254053556
# p-value: 3.968396708878063e-06
# Critical Value (1%): -3.4360490926821727
# Critical Value (5%): -2.8640565321870635
# Critical Value (10%): -2.5681098631379964
#
# Stationarity test for USDT_Volume
# ADF Statistic: -2.742672101127422
# p-value: 0.06694070265509197
# Critical Value (1%): -3.436064032324827
# Critical Value (5%): -2.864063122757945
# Critical Value (10%): -2.5681133731450605
#
# Stationarity test for USDC_number_of_transfers
# ADF Statistic: -3.424231900472734
# p-value: 0.01016002828919684
# Critical Value (1%): -3.4360991979671205
# Critical Value (5%): -2.864078635828568
# Critical Value (10%): -2.568121635118498
#
# Stationarity test for USDC_on_chain_volume
# ADF Statistic: -2.854333578178688
# p-value: 0.05092193015822676
# Critical Value (1%): -3.4361042569951805
# Critical Value (5%): -2.8640808675675826
# Critical Value (10%): -2.568122823703617
#
# Stationarity test for USDC_Price
# ADF Statistic: -15.225707000896316
# p-value: 5.407669171822505e-28
# Critical Value (1%): -3.435999853208029
# Critical Value (5%): -2.864034810134692
# Critical Value (10%): -2.5680982944411417
#
# Stationarity test for USDC_Volume
# ADF Statistic: -6.87576394998766
# p-value: 1.4760415836652545e-09
# Critical Value (1%): -3.4361042569951805
# Critical Value (5%): -2.8640808675675826
# Critical Value (10%): -2.568122823703617
#
# Stationarity test for MATIC_number_of_transfers
# ADF Statistic: -2.7191262332572905
# p-value: 0.07078666869959832
# Critical Value (1%): -3.4360991979671205
# Critical Value (5%): -2.864078635828568
# Critical Value (10%): -2.568121635118498
#
# Stationarity test for MATIC_on_chain_volume
# ADF Statistic: -4.888985460778217
# p-value: 3.6637502758062926e-05
# Critical Value (1%): -3.4360590437486405
# Critical Value (5%): -2.864060922068716
# Critical Value (10%): -2.5681122011011426
#
# Stationarity test for MATIC_Price
# ADF Statistic: -1.9891613184741948
# p-value: 0.2913456111636984
# Critical Value (1%): -3.4360194465416387
# Critical Value (5%): -2.8640434537995523
# Critical Value (10%): -2.5681028978640104
#
# Stationarity test for MATIC_Volume
# ADF Statistic: -4.118740430102675
# p-value: 0.0009017028293310284
# Critical Value (1%): -3.4360991979671205
# Critical Value (5%): -2.864078635828568
# Critical Value (10%): -2.568121635118498
#
# Stationarity test for SHIB_number_of_transfers
# ADF Statistic: -3.359519279018931
# p-value: 0.012418739159689359
# Critical Value (1%): -3.4360941478268767
# Critical Value (5%): -2.864076408006588
# Critical Value (10%): -2.568120448620112
#
# Stationarity test for SHIB_on_chain_volume
# ADF Statistic: -8.53604287824094
# p-value: 1.0073917200631604e-13
# Critical Value (1%): -3.4360342309571053
# Critical Value (5%): -2.864049975956835
# Critical Value (10%): -2.568106371425197
#
# Stationarity test for SHIB_Price
# ADF Statistic: -2.691451440344797
# p-value: 0.07552926113275193
# Critical Value (1%): -3.4361042569951805
# Critical Value (5%): -2.8640808675675826
# Critical Value (10%): -2.568122823703617
#
# Stationarity test for SHIB_Volume
# ADF Statistic: -3.9456604538548907
# p-value: 0.0017233606176388216
# Critical Value (1%): -3.4361042569951805
# Critical Value (5%): -2.8640808675675826
# Critical Value (10%): -2.568122823703617
#
# Stationarity test for WETH_number_of_transfers
# ADF Statistic: -2.730582220646327
# p-value: 0.06889406152960471
# Critical Value (1%): -3.4361042569951805
# Critical Value (5%): -2.8640808675675826
# Critical Value (10%): -2.568122823703617
#
# Stationarity test for WETH_on_chain_volume
# ADF Statistic: -5.463443416962711
# p-value: 2.4889725089128686e-06
# Critical Value (1%): -3.436039176245612
# Critical Value (5%): -2.8640521575678655
# Critical Value (10%): -2.5681075333056036
#
# Stationarity test for WETH_Price
# ADF Statistic: -2.0940484693848127
# p-value: 0.24691446650749088
# Critical Value (1%): -3.4360194465416387
# Critical Value (5%): -2.8640434537995523
# Critical Value (10%): -2.5681028978640104
#
# Stationarity test for WETH_Volume
# ADF Statistic: -33.98861898528512
# p-value: 0.0
# Critical Value (1%): -3.4359901072390353
# Critical Value (5%): -2.86403051064684
# Critical Value (10%): -2.5680960046332366
#
# Stationarity test for DAI_number_of_transfers
# ADF Statistic: -2.860861461517898
# p-value: 0.05009225064572091
# Critical Value (1%): -3.4360490926821727
# Critical Value (5%): -2.8640565321870635
# Critical Value (10%): -2.5681098631379964
#
# Stationarity test for DAI_on_chain_volume
# ADF Statistic: -5.541081275495771
# p-value: 1.701115742334783e-06
# Critical Value (1%): -3.4360194465416387
# Critical Value (5%): -2.8640434537995523
# Critical Value (10%): -2.5681028978640104
#
# Stationarity test for DAI_Price
# ADF Statistic: -12.754934241676564
# p-value: 8.378992028252429e-24
# Critical Value (1%): -3.4361042569951805
# Critical Value (5%): -2.8640808675675826
# Critical Value (10%): -2.568122823703617
#
# Stationarity test for DAI_Volume
# ADF Statistic: -5.603464658017108
# p-value: 1.2494958174692353e-06
# Critical Value (1%): -3.4360243661274414
# Critical Value (5%): -2.8640456240825074
# Critical Value (10%): -2.568104053709638
# Stationarity test for new_tokens_monthly_x
# ADF Statistic: -1.5414771984093532
# p-value: 0.5129025752082446
# Critical Value (1%): -3.4359901072390353
# Critical Value (5%): -2.86403051064684
# Critical Value (10%): -2.5680960046332366
#
# Stationarity test for CPILFESL
# ADF Statistic: -0.1981267656140812
# p-value: 0.9387445339387863
# Critical Value (1%): -3.4359901072390353
# Critical Value (5%): -2.86403051064684
# Critical Value (10%): -2.5680960046332366
#
# Stationarity test for EUEPUINDXM
# ADF Statistic: -2.4283294371230313
# p-value: 0.13389973709844627
# Critical Value (1%): -3.4359901072390353
# Critical Value (5%): -2.86403051064684
# Critical Value (10%): -2.5680960046332366
#
# Stationarity test for CHNMAINLANDEPU
# ADF Statistic: -3.312743035204589
# p-value: 0.014318381190617126
# Critical Value (1%): -3.4359901072390353
# Critical Value (5%): -2.86403051064684
# Critical Value (10%): -2.5680960046332366
#
# Stationarity test for NASDAQ_Close
# ADF Statistic: -1.8679388577868377
# p-value: 0.347290680554707
# Critical Value (1%): -3.436064032324827
# Critical Value (5%): -2.864063122757945
# Critical Value (10%): -2.5681133731450605
#
# Stationarity test for NASDAQ_Volume
# ADF Statistic: -4.105930782641187
# p-value: 0.0009468918425193674
# Critical Value (1%): -3.4360590437486405
# Critical Value (5%): -2.864060922068716
# Critical Value (10%): -2.5681122011011426
#
# Stationarity test for TNX_Close
# ADF Statistic: 0.02722378084822337
# p-value: 0.9607263975998537
# Critical Value (1%): -3.4359901072390353
# Critical Value (5%): -2.86403051064684
# Critical Value (10%): -2.5680960046332366
#
# Stationarity test for USEPUINDXD
# ADF Statistic: -3.7557906652373703
# p-value: 0.003393441136312077
# Critical Value (1%): -3.436089106551049
# Critical Value (5%): -2.864074184091338
# Critical Value (10%): -2.568119264202968
#
# Stationarity test for FFR
# ADF Statistic: 0.8493578714275938
# p-value: 0.9923925317825069
# Critical Value (1%): -3.4359901072390353
# Critical Value (5%): -2.86403051064684
# Critical Value (10%): -2.5680960046332366
#
# Stationarity test for NIKKEI225
# ADF Statistic: -2.4238111518450776
# p-value: 0.13512835030112114
# Critical Value (1%): -3.435999853208029
# Critical Value (5%): -2.864034810134692
# Critical Value (10%): -2.5680982944411417
#
# Stationarity test for DCOILBRENTEU
# ADF Statistic: -2.144504823977069
# p-value: 0.22699942561303837
# Critical Value (1%): -3.4360991979671205
# Critical Value (5%): -2.864078635828568
# Critical Value (10%): -2.568121635118498
#
# Stationarity test for SP500
# ADF Statistic: -2.3714547711635547
# p-value: 0.1499556782458798
# Critical Value (1%): -3.4359901072390353
# Critical Value (5%): -2.86403051064684
# Critical Value (10%): -2.5680960046332366
#
# Stationarity test for GOOGTREND
# ADF Statistic: -3.9181467489263024
# p-value: 0.001905282561891544
# Critical Value (1%): -3.4360991979671205
# Critical Value (5%): -2.864078635828568
# Critical Value (10%): -2.568121635118498
#
# Stationarity test for TRX_Close
# ADF Statistic: -2.30769743797503
# p-value: 0.16949741176954658
# Critical Value (1%): -3.4360840741163168
# Critical Value (5%): -2.864071964072552
# Critical Value (10%): -2.568118081861596
#
# Stationarity test for TRX_Volume
# ADF Statistic: -3.6944186491714897
# p-value: 0.004192349290412672
# Critical Value (1%): -3.4360540638753405
# Critical Value (5%): -2.864058725215095
# Critical Value (10%): -2.568111031100567
#
# Stationarity test for XRP_Close
# ADF Statistic: -2.67524867799159
# p-value: 0.07842012970430363
# Critical Value (1%): -3.4361042569951805
# Critical Value (5%): -2.8640808675675826
# Critical Value (10%): -2.568122823703617
#
# Stationarity test for XRP_Volume
# ADF Statistic: -2.899855226650482
# p-value: 0.0453648352331207
# Critical Value (1%): -3.436089106551049
# Critical Value (5%): -2.864074184091338
# Critical Value (10%): -2.568119264202968
#
# Stationarity test for DOT_Close
# ADF Statistic: -1.6317841721552437
# p-value: 0.46655694474746406
# Critical Value (1%): -3.4360342309571053
# Critical Value (5%): -2.864049975956835
# Critical Value (10%): -2.568106371425197
#
# Stationarity test for DOT_Volume
# ADF Statistic: -2.781028214900925
# p-value: 0.06103527096467548
# Critical Value (1%): -3.436064032324827
# Critical Value (5%): -2.864063122757945
# Critical Value (10%): -2.5681133731450605
#
# Stationarity test for ADA_Close
# ADF Statistic: -1.7038404589508762
# p-value: 0.4291348511017756
# Critical Value (1%): -3.4360991979671205
# Critical Value (5%): -2.864078635828568
# Critical Value (10%): -2.568121635118498
#
# Stationarity test for ADA_Volume
# ADF Statistic: -2.927884149242442
# p-value: 0.04220021128793812
# Critical Value (1%): -3.436089106551049
# Critical Value (5%): -2.864074184091338
# Critical Value (10%): -2.568119264202968
#
# Stationarity test for BNB_Close
# ADF Statistic: -2.2511876323899473
# p-value: 0.1881942353347112
# Critical Value (1%): -3.4360194465416387
# Critical Value (5%): -2.8640434537995523
# Critical Value (10%): -2.5681028978640104
#
# Stationarity test for BNB_Volume
# ADF Statistic: -3.498362796629069
# p-value: 0.008029240600020063
# Critical Value (1%): -3.4360941478268767
# Critical Value (5%): -2.864076408006588
# Critical Value (10%): -2.568120448620112
#
# Stationarity test for SOL_Close
# ADF Statistic: -1.8068626139529391
# p-value: 0.37705995846577933
# Critical Value (1%): -3.4360991979671205
# Critical Value (5%): -2.864078635828568
# Critical Value (10%): -2.568121635118498
#
# Stationarity test for SOL_Volume
# ADF Statistic: -2.99327164640182
# p-value: 0.03552753932416774
# Critical Value (1%): -3.4360991979671205
# Critical Value (5%): -2.864078635828568
# Critical Value (10%): -2.568121635118498
#
# Stationarity test for DOGE_Close
# ADF Statistic: -2.4661110934691393
# p-value: 0.12393906415417782
# Critical Value (1%): -3.4361042569951805
# Critical Value (5%): -2.8640808675675826
# Critical Value (10%): -2.568122823703617
#
# Stationarity test for DOGE_Volume
# ADF Statistic: -3.775557205599516
# p-value: 0.0031675341065629183
# Critical Value (1%): -3.4361042569951805
# Critical Value (5%): -2.8640808675675826
# Critical Value (10%): -2.568122823703617
#
# Stationarity test for ETH_Price
# ADF Statistic: -13.149227490485952
# p-value: 1.3779191607961552e-24
# Critical Value (1%): -3.4360194465416387
# Critical Value (5%): -2.8640434537995523
# Critical Value (10%): -2.5681028978640104
#
# Stationarity test for ETH_Volume
# ADF Statistic: -8.174930662238092
# p-value: 8.426849532019233e-13
# Critical Value (1%): -3.4360941478268767
# Critical Value (5%): -2.864076408006588
# Critical Value (10%): -2.568120448620112
#
# Stationarity test for BTC_Price
# ADF Statistic: -6.5557620993455945
# p-value: 8.624896551138307e-09
# Critical Value (1%): -3.4361093249345402
# Critical Value (5%): -2.8640831032339706
# Critical Value (10%): -2.5681240143809787
#
# Stationarity test for BTC_Volume
# ADF Statistic: -14.405130240183938
# p-value: 8.382202279649016e-27
# Critical Value (1%): -3.4360590437486405
# Critical Value (5%): -2.864060922068716
# Critical Value (10%): -2.5681122011011426
#
# Stationarity test for LINK_number_of_transfers
# ADF Statistic: -16.051108964938276
# p-value: 5.773263864823123e-29
# Critical Value (1%): -3.4360540638753405
# Critical Value (5%): -2.864058725215095
# Critical Value (10%): -2.568111031100567
#
# Stationarity test for LINK_on_chain_volume
# ADF Statistic: -16.15965154231521
# p-value: 4.4797735129196126e-29
# Critical Value (1%): -3.4360540638753405
# Critical Value (5%): -2.864058725215095
# Critical Value (10%): -2.568111031100567
#
# Stationarity test for LINK_Price
# ADF Statistic: -7.64870244738342
# p-value: 1.8134251792246166e-11
# Critical Value (1%): -3.4360941478268767
# Critical Value (5%): -2.864076408006588
# Critical Value (10%): -2.568120448620112
#
# Stationarity test for LINK_Volume
# ADF Statistic: -12.787175584925107
# p-value: 7.20501408987261e-24
# Critical Value (1%): -3.436089106551049
# Critical Value (5%): -2.864074184091338
# Critical Value (10%): -2.568119264202968
#
# Stationarity test for GWEI_average_daily_gas_price_gwei
# ADF Statistic: -13.056835190936287
# p-value: 2.086416199577479e-24
# Critical Value (1%): -3.4360941478268767
# Critical Value (5%): -2.864076408006588
# Critical Value (10%): -2.568120448620112
#
# Stationarity test for WBTC_number_of_transfers
# ADF Statistic: -12.652904208453355
# p-value: 1.3561387359449075e-23
# Critical Value (1%): -3.436064032324827
# Critical Value (5%): -2.864063122757945
# Critical Value (10%): -2.5681133731450605
#
# Stationarity test for WBTC_on_chain_volume
# ADF Statistic: -11.076470205044414
# p-value: 4.4197216328319705e-20
# Critical Value (1%): -3.4361042569951805
# Critical Value (5%): -2.8640808675675826
# Critical Value (10%): -2.568122823703617
#
# Stationarity test for WBTC_Price
# ADF Statistic: -6.567645340914483
# p-value: 8.083437682495569e-09
# Critical Value (1%): -3.4361093249345402
# Critical Value (5%): -2.8640831032339706
# Critical Value (10%): -2.5681240143809787
# Stationarity test for WBTC_Volume
# ADF Statistic: -13.846954699130494
# p-value: 7.120330040051577e-26
# Critical Value (1%): -3.4360590437486405
# Critical Value (5%): -2.864060922068716
# Critical Value (10%): -2.5681122011011426
#
# Stationarity test for USDT_number_of_transfers
# ADF Statistic: -11.771571064103341
# p-value: 1.0868051591121041e-21
# Critical Value (1%): -3.4360941478268767
# Critical Value (5%): -2.864076408006588
# Critical Value (10%): -2.568120448620112
#
# Stationarity test for USDT_on_chain_volume
# ADF Statistic: -12.3262444619694
# p-value: 6.579448484936728e-23
# Critical Value (1%): -3.436089106551049
# Critical Value (5%): -2.864074184091338
# Critical Value (10%): -2.568119264202968
#
# Stationarity test for USDT_Price
# ADF Statistic: -11.196645235026583
# p-value: 2.2976739078421686e-20
# Critical Value (1%): -3.4360941478268767
# Critical Value (5%): -2.864076408006588
# Critical Value (10%): -2.568120448620112
#
# Stationarity test for USDT_Volume
# ADF Statistic: -14.207096349546338
# p-value: 1.747194413015981e-26
# Critical Value (1%): -3.4360540638753405
# Critical Value (5%): -2.864058725215095
# Critical Value (10%): -2.568111031100567
#
# Stationarity test for USDC_number_of_transfers
# ADF Statistic: -9.860188607653434
# p-value: 4.253450667459593e-17
# Critical Value (1%): -3.4360991979671205
# Critical Value (5%): -2.864078635828568
# Critical Value (10%): -2.568121635118498
#
# Stationarity test for USDC_on_chain_volume
# ADF Statistic: -10.412165765310487
# p-value: 1.7923865884694893e-18
# Critical Value (1%): -3.4361042569951805
# Critical Value (5%): -2.8640808675675826
# Critical Value (10%): -2.568122823703617
#
# Stationarity test for USDC_Price
# ADF Statistic: -14.282605660554925
# p-value: 1.3161564548692244e-26
# Critical Value (1%): -3.436064032324827
# Critical Value (5%): -2.864063122757945
# Critical Value (10%): -2.5681133731450605
#
# Stationarity test for USDC_Volume
# ADF Statistic: -10.698720748857738
# p-value: 3.568835975491534e-19
# Critical Value (1%): -3.4361042569951805
# Critical Value (5%): -2.8640808675675826
# Critical Value (10%): -2.568122823703617
#
# Stationarity test for MATIC_number_of_transfers
# ADF Statistic: -8.2285209502842
# p-value: 6.152412563981362e-13
# Critical Value (1%): -3.4360991979671205
# Critical Value (5%): -2.864078635828568
# Critical Value (10%): -2.568121635118498
#
# Stationarity test for MATIC_on_chain_volume
# ADF Statistic: -11.355645395549876
# p-value: 9.749984426624276e-21
# Critical Value (1%): -3.4361042569951805
# Critical Value (5%): -2.8640808675675826
# Critical Value (10%): -2.568122823703617
#
# Stationarity test for MATIC_Price
# ADF Statistic: -15.575955587944982
# p-value: 1.9597949606089268e-28
# Critical Value (1%): -3.4360194465416387
# Critical Value (5%): -2.8640434537995523
# Critical Value (10%): -2.5681028978640104
#
# Stationarity test for MATIC_Volume
# ADF Statistic: -10.856856918114673
# p-value: 1.4801002829482403e-19
# Critical Value (1%): -3.4360840741163168
# Critical Value (5%): -2.864071964072552
# Critical Value (10%): -2.568118081861596
#
# Stationarity test for SHIB_number_of_transfers
# ADF Statistic: -10.871132123308222
# p-value: 1.3675941950791557e-19
# Critical Value (1%): -3.4360941478268767
# Critical Value (5%): -2.864076408006588
# Critical Value (10%): -2.568120448620112
#
# Stationarity test for SHIB_on_chain_volume
# ADF Statistic: -11.953976456345142
# p-value: 4.252195419007531e-22
# Critical Value (1%): -3.436089106551049
# Critical Value (5%): -2.864074184091338
# Critical Value (10%): -2.568119264202968
#
# Stationarity test for SHIB_Price
# ADF Statistic: -6.770471869682496
# p-value: 2.649808002626792e-09
# Critical Value (1%): -3.4360941478268767
# Critical Value (5%): -2.864076408006588
# Critical Value (10%): -2.568120448620112
#
# Stationarity test for SHIB_Volume
# ADF Statistic: -9.568500986818643
# p-value: 2.322119672361304e-16
# Critical Value (1%): -3.4361093249345402
# Critical Value (5%): -2.8640831032339706
# Critical Value (10%): -2.5681240143809787
#
# Stationarity test for WETH_number_of_transfers
# ADF Statistic: -7.251823193113028
# p-value: 1.7719060834430682e-10
# Critical Value (1%): -3.4360991979671205
# Critical Value (5%): -2.864078635828568
# Critical Value (10%): -2.568121635118498
#
# Stationarity test for WETH_on_chain_volume
# ADF Statistic: -11.440656334392031
# p-value: 6.190369692812194e-21
# Critical Value (1%): -3.4360941478268767
# Critical Value (5%): -2.864076408006588
# Critical Value (10%): -2.568120448620112
#
# Stationarity test for WETH_Price
# ADF Statistic: -13.089284695603034
# p-value: 1.802476177479921e-24
# Critical Value (1%): -3.4360194465416387
# Critical Value (5%): -2.8640434537995523
# Critical Value (10%): -2.5681028978640104
#
# Stationarity test for WETH_Volume
# ADF Statistic: -12.002873967062703
# p-value: 3.3151281774757423e-22
# Critical Value (1%): -3.4361042569951805
# Critical Value (5%): -2.8640808675675826
# Critical Value (10%): -2.568122823703617
#
# Stationarity test for DAI_number_of_transfers
# ADF Statistic: -10.399910610026183
# p-value: 1.9214438604252027e-18
# Critical Value (1%): -3.436089106551049
# Critical Value (5%): -2.864074184091338
# Critical Value (10%): -2.568119264202968
#
# Stationarity test for DAI_on_chain_volume
# ADF Statistic: -10.005265076478821
# p-value: 1.838630423212848e-17
# Critical Value (1%): -3.436089106551049
# Critical Value (5%): -2.864074184091338
# Critical Value (10%): -2.568119264202968
#
# Stationarity test for DAI_Price
# ADF Statistic: -13.581009507418699
# p-value: 2.123905876789791e-25
# Critical Value (1%): -3.4361093249345402
# Critical Value (5%): -2.8640831032339706
# Critical Value (10%): -2.5681240143809787
#
# Stationarity test for DAI_Volume
# ADF Statistic: -14.23231962193778
# p-value: 1.5887339226557114e-26
# Critical Value (1%): -3.4360540638753405
# Critical Value (5%): -2.864058725215095
# Critical Value (10%): -2.568111031100567
#
# Stationarity test for new_tokens_monthly_x
# ADF Statistic: -34.05181997370039
# p-value: 0.0
# Critical Value (1%): -3.43599497601695
# Critical Value (5%): -2.8640326585367473
# Critical Value (10%): -2.5680971485495068
#
# Stationarity test for CPILFESL
# ADF Statistic: -11.502629302289913
# p-value: 4.453405205657875e-21
# Critical Value (1%): -3.4361093249345402
# Critical Value (5%): -2.8640831032339706
# Critical Value (10%): -2.5681240143809787
#
# Stationarity test for EUEPUINDXM
# ADF Statistic: -34.045531865639475
# p-value: 0.0
# Critical Value (1%): -3.43599497601695
# Critical Value (5%): -2.8640326585367473
# Critical Value (10%): -2.5680971485495068
#
# Stationarity test for CHNMAINLANDEPU
# ADF Statistic: -34.04716275542187
# p-value: 0.0
# Critical Value (1%): -3.43599497601695
# Critical Value (5%): -2.8640326585367473
# Critical Value (10%): -2.5680971485495068
#
# Stationarity test for NASDAQ_Close
# ADF Statistic: -9.412269482946208
# p-value: 5.792558859489071e-16
# Critical Value (1%): -3.4360590437486405
# Critical Value (5%): -2.864060922068716
# Critical Value (10%): -2.5681122011011426
#
# Stationarity test for NASDAQ_Volume
# ADF Statistic: -13.559847073795599
# p-value: 2.321439314988532e-25
# Critical Value (1%): -3.4360590437486405
# Critical Value (5%): -2.864060922068716
# Critical Value (10%): -2.5681122011011426
#
# Stationarity test for TNX_Close
# ADF Statistic: -33.11919353658252
# p-value: 0.0
# Critical Value (1%): -3.43599497601695
# Critical Value (5%): -2.8640326585367473
# Critical Value (10%): -2.5680971485495068
#
# Stationarity test for USEPUINDXD
# ADF Statistic: -12.424445965015174
# p-value: 4.0684517664665605e-23
# Critical Value (1%): -3.436089106551049
# Critical Value (5%): -2.864074184091338
# Critical Value (10%): -2.568119264202968
#
# Stationarity test for FFR
# ADF Statistic: -34.41412463749167
# p-value: 0.0
# Critical Value (1%): -3.43599497601695
# Critical Value (5%): -2.8640326585367473
# Critical Value (10%): -2.5680971485495068
#
# Stationarity test for NIKKEI225
# ADF Statistic: -32.51472758947193
# p-value: 0.0
# Critical Value (1%): -3.43599497601695
# Critical Value (5%): -2.8640326585367473
# Critical Value (10%): -2.5680971485495068
#
# Stationarity test for DCOILBRENTEU
# ADF Statistic: -6.7610386152866
# p-value: 2.7918702281422187e-09
# Critical Value (1%): -3.4360991979671205
# Critical Value (5%): -2.864078635828568
# Critical Value (10%): -2.568121635118498
#
# Stationarity test for SP500
# ADF Statistic: -33.143016023470395
# p-value: 0.0
# Critical Value (1%): -3.43599497601695
# Critical Value (5%): -2.8640326585367473
# Critical Value (10%): -2.5680971485495068
#
# Stationarity test for GOOGTREND
# ADF Statistic: -8.016491775299178
# p-value: 2.1319946820331795e-12
# Critical Value (1%): -3.4361093249345402
# Critical Value (5%): -2.8640831032339706
# Critical Value (10%): -2.5681240143809787
#
# Stationarity test for TRX_Close
# ADF Statistic: -9.146551190726527
# p-value: 2.7580295152618482e-15
# Critical Value (1%): -3.4360840741163168
# Critical Value (5%): -2.864071964072552
# Critical Value (10%): -2.568118081861596
#
# Stationarity test for TRX_Volume
# ADF Statistic: -11.706333944202836
# p-value: 1.5257677148664631e-21
# Critical Value (1%): -3.4360540638753405
# Critical Value (5%): -2.864058725215095
# Critical Value (10%): -2.568111031100567
# Stationarity test for XRP_Close
# ADF Statistic: -7.123820852458182
# p-value: 3.6638959242780043e-10
# Critical Value (1%): -3.4361042569951805
# Critical Value (5%): -2.8640808675675826
# Critical Value (10%): -2.568122823703617
#
# Stationarity test for XRP_Volume
# ADF Statistic: -11.774074779860522
# p-value: 1.0727868158362064e-21
# Critical Value (1%): -3.436089106551049
# Critical Value (5%): -2.864074184091338
# Critical Value (10%): -2.568119264202968
#
# Stationarity test for DOT_Close
# ADF Statistic: -11.003079908991978
# p-value: 6.606997194493412e-20
# Critical Value (1%): -3.4360342309571053
# Critical Value (5%): -2.864049975956835
# Critical Value (10%): -2.568106371425197
#
# Stationarity test for DOT_Volume
# ADF Statistic: -14.578465485559919
# p-value: 4.5087448644258444e-27
# Critical Value (1%): -3.4360490926821727
# Critical Value (5%): -2.8640565321870635
# Critical Value (10%): -2.5681098631379964
#
# Stationarity test for ADA_Close
# ADF Statistic: -6.564481423726867
# p-value: 8.224236568114506e-09
# Critical Value (1%): -3.4360991979671205
# Critical Value (5%): -2.864078635828568
# Critical Value (10%): -2.568121635118498
#
# Stationarity test for ADA_Volume
# ADF Statistic: -8.75511281328211
# p-value: 2.7688622492129836e-14
# Critical Value (1%): -3.4361093249345402
# Critical Value (5%): -2.8640831032339706
# Critical Value (10%): -2.5681240143809787
#
# Stationarity test for BNB_Close
# ADF Statistic: -6.75750737166384
# p-value: 2.84696322926809e-09
# Critical Value (1%): -3.4361093249345402
# Critical Value (5%): -2.8640831032339706
# Critical Value (10%): -2.5681240143809787
#
# Stationarity test for BNB_Volume
# ADF Statistic: -8.044977058453394
# p-value: 1.8047063471881875e-12
# Critical Value (1%): -3.4360941478268767
# Critical Value (5%): -2.864076408006588
# Critical Value (10%): -2.568120448620112
#
# Stationarity test for SOL_Close
# ADF Statistic: -5.47234791389243
# p-value: 2.3831286457753318e-06
# Critical Value (1%): -3.4361093249345402
# Critical Value (5%): -2.8640831032339706
# Critical Value (10%): -2.5681240143809787
#
# Stationarity test for SOL_Volume
# ADF Statistic: -9.555501234772237
# p-value: 2.5053365668890735e-16
# Critical Value (1%): -3.4360991979671205
# Critical Value (5%): -2.864078635828568
# Critical Value (10%): -2.568121635118498
#
# Stationarity test for DOGE_Close
# ADF Statistic: -7.223187811932646
# p-value: 2.085444196972325e-10
# Critical Value (1%): -3.4361093249345402
# Critical Value (5%): -2.8640831032339706
# Critical Value (10%): -2.5681240143809787
#
# Stationarity test for DOGE_Volume
# ADF Statistic: -9.090463888626326
# p-value: 3.836705678690898e-15
# Critical Value (1%): -3.4361042569951805
# Critical Value (5%): -2.8640808675675826
# Critical Value (10%): -2.568122823703617

# %%
# Continue with the recursive window prediction using the optimal lag
ar_predictions = []
for i in range(start, n):
    y_train_ar = Y[:i]
    ar_model = AutoReg(y_train_ar, lags=1, old_names=False).fit()
    y_pred_ar = ar_model.predict(start=i, end=i)
    ar_predictions.append(y_pred_ar[0])

# Calculate RMSE for the AR predictions
ar_rmse = np.sqrt(mean_squared_error(Y[start:], ar_predictions))
print(f"AR Model RMSE for the last 100 values: {ar_rmse}")
# Out:
# AR Model RMSE for the last 100 values: 0.2758212041945253
